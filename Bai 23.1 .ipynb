# %%
#bai23.1
import folium

# Tọa độ UEH (cơ sở Nguyễn Tri Phương)
ueh_location = [10.761285072889024, 106.6683579950703]
m = folium.Map(location=ueh_location, zoom_start=16)

# marker UEH
folium.Marker(
    ueh_location,
    popup="Đại học UEH",
    tooltip="Click để xem",
    icon=folium.Icon(color='red', icon='university', prefix='fa')
).add_to(m)

#5 địa điểm công cộng
public_places = [
    {"name": "Bệnh viện 30-4 ", "coord": [10.759758266094773, 106.67490160591802]},
    {"name": "Công viên Lê Thị Riêng ", "coord": [10.786012022953196, 106.66492036062307]},
    {"name": "Nhà hàng Gần Đây ", "coord": [10.765090899144099, 106.66804830524066]},
    {"name": "Trạm xe buýt NTP ", "coord": [10.761434510526863, 106.66863949537901]},
    {"name": " Chợ Nhật Tảo ", "coord": [10.76490646992333, 106.66793565274165]}
]

for place in public_places:
    folium.Marker(place["coord"], popup=place["name"]).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_643251355f557097091401946ba98412 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_643251355f557097091401946ba98412&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_643251355f557097091401946ba98412 = L.map(
#                 &quot;map_643251355f557097091401946ba98412&quot;,
#                 {
#                     center: [10.761285072889024, 106.6683579950703],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f645b08fe8785d19b66b920069d7f516 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f645b08fe8785d19b66b920069d7f516.addTo(map_643251355f557097091401946ba98412);
#
#
#             var marker_bfb0c6ee1520c781ac1c203d5ebaa08d = L.marker(
#                 [10.761285072889024, 106.6683579950703],
#                 {
# }
#             ).addTo(map_643251355f557097091401946ba98412);
#
#
#             var icon_b319c86a4a9dd8ddd7c116baf33c1cb0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;university&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6e1a8e5c6ed08e51aa5988834c6e0400 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24ba9962a4eab883f83a0717d2c6464e = $(`&lt;div id=&quot;html_24ba9962a4eab883f83a0717d2c6464e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Đại học UEH&lt;/div&gt;`)[0];
#                 popup_6e1a8e5c6ed08e51aa5988834c6e0400.setContent(html_24ba9962a4eab883f83a0717d2c6464e);
#
#
#
#         marker_bfb0c6ee1520c781ac1c203d5ebaa08d.bindPopup(popup_6e1a8e5c6ed08e51aa5988834c6e0400)
#         ;
#
#
#
#
#             marker_bfb0c6ee1520c781ac1c203d5ebaa08d.bindTooltip(
#                 `&lt;div&gt;
#                      Click để xem
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_bfb0c6ee1520c781ac1c203d5ebaa08d.setIcon(icon_b319c86a4a9dd8ddd7c116baf33c1cb0);
#
#
#             var marker_f5a20b0839e638d884929010bb2cbbf8 = L.marker(
#                 [10.759758266094773, 106.67490160591802],
#                 {
# }
#             ).addTo(map_643251355f557097091401946ba98412);
#
#
#         var popup_6e0d6995d6357bb5c67d2a6c72ac8224 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1312cdecab4e2204d7dadbee3a451d21 = $(`&lt;div id=&quot;html_1312cdecab4e2204d7dadbee3a451d21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bệnh viện 30-4 &lt;/div&gt;`)[0];
#                 popup_6e0d6995d6357bb5c67d2a6c72ac8224.setContent(html_1312cdecab4e2204d7dadbee3a451d21);
#
#
#
#         marker_f5a20b0839e638d884929010bb2cbbf8.bindPopup(popup_6e0d6995d6357bb5c67d2a6c72ac8224)
#         ;
#
#
#
#
#             var marker_3453da9b2f596fc1ef07af78d00c8053 = L.marker(
#                 [10.786012022953196, 106.66492036062307],
#                 {
# }
#             ).addTo(map_643251355f557097091401946ba98412);
#
#
#         var popup_307321fb82bd09aead4a0ec08a0d801f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe00a8102d537b89341bf565069ea27d = $(`&lt;div id=&quot;html_fe00a8102d537b89341bf565069ea27d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Công viên Lê Thị Riêng &lt;/div&gt;`)[0];
#                 popup_307321fb82bd09aead4a0ec08a0d801f.setContent(html_fe00a8102d537b89341bf565069ea27d);
#
#
#
#         marker_3453da9b2f596fc1ef07af78d00c8053.bindPopup(popup_307321fb82bd09aead4a0ec08a0d801f)
#         ;
#
#
#
#
#             var marker_861e0fa7ddd9cd0326a6c899971174a6 = L.marker(
#                 [10.765090899144099, 106.66804830524066],
#                 {
# }
#             ).addTo(map_643251355f557097091401946ba98412);
#
#
#         var popup_70ef6b5060cf05697f5995d0bb457ab8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4656ff381946d9902970e2a2fbbfe285 = $(`&lt;div id=&quot;html_4656ff381946d9902970e2a2fbbfe285&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nhà hàng Gần Đây &lt;/div&gt;`)[0];
#                 popup_70ef6b5060cf05697f5995d0bb457ab8.setContent(html_4656ff381946d9902970e2a2fbbfe285);
